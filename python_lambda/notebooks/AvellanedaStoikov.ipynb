# %%
# %matplotlib notebook
# !git pull
import os;os.environ['LAMBDA_PARQUET_TICK_DB']=rf'X:\lambda_data'
# Out:
# Already up to date.

# %%
from notebooks.lambda_imports import *
plt.rcParams['figure.figsize'] = [10, 7]
# plot_with_dark_style()
# Out:
# PROJECT_PATH=E:\javif\Coding\Python\market_making_fw\python_lambda
# BACKTEST_OUTPUT_PATH(LAMBDA_OUTPUT_PATH)=E:\javif\Coding\Python\market_making_fw\python_lambda\output
# BACKTEST_TEMP_PATH(LAMBDA_TEMP_PATH)=E:\javif\Coding\Python\market_making_fw\python_lambda\temp
# BACKTEST_JAR_PATH(LAMBDA_JAR_PATH)=E:\javif\Coding\Python\market_making_fw\java\executables\Backtest\target\Backtest.jar
# log_path(LAMBDA_LOGS_PATH)=E:\javif\Coding\Python\market_making_fw\python_lambda\logs
# PARQUET_PATH_DB(LAMBDA_PARQUET_TICK_DB)=X:\lambda_data

# %%
# plt.figure()
# plt.show()

# %%
DEBUG=False

# %%
session_name='AvellanedaStoikovNotebook'
load_notebook_session(session_name)
# Out:
# notebook session file found AvellanedaStoikovNotebook

# %% [markdown]
# # Properties

# %% [markdown]
# ## Algorithm

# %%
parameters_default = {
    # Avellaneda default
    "risk_aversion": (0.9),
    "position_multiplier": (100),
    "window_tick": (10),
    "minutes_change_k": (10),
    "quantity": (0.0001),
    "k_default": (0.00769),
    "spread_multiplier": (5.0),
    "first_hour": (7),
    "last_hour": (19),
}


algorithm_info='as_as_notebook'
algorithm = AvellanedaStoikov(algorithm_info=algorithm_info,parameters=parameters_default)

# %% [markdown]
# ## Backtest

# %%
instrument_pk='btcusdt_binance'

start_date_pt=datetime.datetime(year=2020, day=8, month=12,hour=9)
end_date_pt=datetime.datetime(year=2020, day=8, month=12,hour=13)

start_date_train=end_date_pt+datetime.timedelta(hours=1)#not here
end_date_train=start_date_train+datetime.timedelta(hours=2)#not here

start_date_test=end_date_train+datetime.timedelta(hours=1)
end_date_test=start_date_test+datetime.timedelta(hours=2)

# %% [markdown]
# ## Genetic algorithm configuration

# %%
ga_configuration = GAConfiguration
if DEBUG:
    ga_configuration.population = 15
    ga_configuration_generations=3
    ga_configuration_simultaneous=15
else:
    ga_configuration.population = 45
    ga_configuration_generations=15
    ga_configuration_simultaneous=45

ga_configuration.decay=1/float(ga_configuration_generations)

# %% [markdown]
# # Parameter tuning

# %%
parameters_min = {"risk_aversion":0.01,'window_tick':5,'k_default':0. ,'spread_multiplier':1.}
parameters_max = {"risk_aversion":0.9, 'window_tick':25,'k_default':2. ,'spread_multiplier':2.}

# %%
best_param_dict, summary_df =algorithm.parameter_tuning(
    instrument_pk=instrument_pk,
    start_date=start_date_pt,
    end_date=end_date_pt,
    parameters_min=parameters_min,
    parameters_max=parameters_max,
    generations=ga_configuration_generations,
    ga_configuration=ga_configuration,
	max_simultaneous=ga_configuration_simultaneous
)
# Out:
# initial [0]{
#     "risk_aversion": 0.16412610253303278,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [1]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.7159824054399095,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [2]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [3]{
#     "risk_aversion": 0.7536606511126509,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [4]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.9077716869826147,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [5]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.29705947837640156,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [6]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.9166600701936054,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [7]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [8]{
#     "risk_aversion": 0.8002615850018837,
#     "position_multiplier": 100.0,
#     "window_tick": 19.75842300788814,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [9]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [10]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [11]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [12]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [13]{
#     "risk_aversion": 0.1041254222746309,
#     "position_multiplier": 100.0,
#     "window_tick": 22.712101806469775,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [14]{
#     "risk_aversion": 0.3841825009874846,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [15]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.3017694457525146,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [16]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 22.875239129104862,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.8560564079382353,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [17]{
#     "risk_aversion": 0.028035169402415017,
#     "position_multiplier": 100.0,
#     "window_tick": 15.175018638480596,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [18]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [19]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.3297505829053735,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [20]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 13.274075200809499,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.8480808153827756,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [21]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.2286157760814844,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [22]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.523163494562559,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [23]{
#     "risk_aversion": 0.17102523459829272,
#     "position_multiplier": 100.0,
#     "window_tick": 5.28752622018196,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [24]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.7908398142197663,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [25]{
#     "risk_aversion": 0.09131489055720851,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [26]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.4811467371925802,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [27]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 12.49856338468752,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [28]{
#     "risk_aversion": 0.46672190963386034,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [29]{
#     "risk_aversion": 0.8066911554752049,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.8534480994396296,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [30]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0873556361158063,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [31]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [32]{
#     "risk_aversion": 0.30668094406004903,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [33]{
#     "risk_aversion": 0.06543373489662538,
#     "position_multiplier": 100.0,
#     "window_tick": 23.46480655188303,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.7610141535589277,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [34]{
#     "risk_aversion": 0.838071047202183,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.4972929307193095,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [35]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 9.866473644574304,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [36]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [37]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [38]{
#     "risk_aversion": 0.5042796011928666,
#     "position_multiplier": 100.0,
#     "window_tick": 12.681330927406965,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [39]{
#     "risk_aversion": 0.6181028820801832,
#     "position_multiplier": 100.0,
#     "window_tick": 11.172267619889633,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [40]{
#     "risk_aversion": 0.14976010093011222,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [41]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [42]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.0845572302235067,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [43]{
#     "risk_aversion": 0.22833946238107128,
#     "position_multiplier": 100.0,
#     "window_tick": 12.286247131104068,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.1280292631327758,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# initial [44]{
#     "risk_aversion": 0.4676889272532547,
#     "position_multiplier": 100.0,
#     "window_tick": 7.827207919314038,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.8328608418949632,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# launching AvellanedaStoikov_ga_0
# launching AvellanedaStoikov_ga_1
# launching AvellanedaStoikov_ga_2
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_3
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebookslaunching AvellanedaStoikov_ga_4
#
# launching AvellanedaStoikov_ga_5
# launching AvellanedaStoikov_ga_6pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
#
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebookslaunching AvellanedaStoikov_ga_7pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
#
#
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_8pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
#
# launching AvellanedaStoikov_ga_9
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_10
# launching AvellanedaStoikov_ga_11
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_12
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_13
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_14pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
#
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_15pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
#
# launching AvellanedaStoikov_ga_16
# launching AvellanedaStoikov_ga_17
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# launching AvellanedaStoikov_ga_18
# launching AvellanedaStoikov_ga_19
# launching AvellanedaStoikov_ga_20pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
#
output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_1_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_2 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_2_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_3 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_3_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_4 with 13164 trades
# AvellanedaStoikov_ga_5 with 13141 trades
# AvellanedaStoikov_ga_6 with 13084 trades
# AvellanedaStoikov_ga_7 with 13229 trades
# AvellanedaStoikov_ga_8 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_8_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_9 with 13130 trades
# AvellanedaStoikov_ga_10 with 13140 trades
# AvellanedaStoikov_ga_11 with 13113 trades
# AvellanedaStoikov_ga_12 with 13163 trades
# AvellanedaStoikov_ga_13 with 13163 trades
# AvellanedaStoikov_ga_14 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_14_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_15 with 13135 trades
# AvellanedaStoikov_ga_16 with 13188 trades
# AvellanedaStoikov_ga_17 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_17_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_18 with 13072 trades
# AvellanedaStoikov_ga_19 with 13091 trades
# AvellanedaStoikov_ga_20 with 13140 trades
# AvellanedaStoikov_ga_21 with 13140 trades
# AvellanedaStoikov_ga_22 with 13140 trades
# AvellanedaStoikov_ga_23 with 13162 trades
# AvellanedaStoikov_ga_24 with 13139 trades
# AvellanedaStoikov_ga_25 with 13153 trades
# AvellanedaStoikov_ga_26 with 13140 trades
# AvellanedaStoikov_ga_27 with 13077 trades
# AvellanedaStoikov_ga_28 with 13151 trades
# AvellanedaStoikov_ga_29 with 13229 trades
# AvellanedaStoikov_ga_30 with 13115 trades
# AvellanedaStoikov_ga_31 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_31_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_32 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_32_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_33 with 13137 trades
# AvellanedaStoikov_ga_34 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_34_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_35 with 13086 trades
# AvellanedaStoikov_ga_36 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_36_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_37 with 13140 trades
# AvellanedaStoikov_ga_38 with 13147 trades
# AvellanedaStoikov_ga_39 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_39_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_40 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_40_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_41 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_41_btcusdt_binance_btcusdt_binance.csv not exist
# AvellanedaStoikov_ga_42 with 13140 trades
# AvellanedaStoikov_ga_43 with 13141 trades
# AvellanedaStoikov_ga_44 output file E:\javif\Coding\Python\market_making_fw\python_lambda\output\trades_table_AvellanedaStoikov_ga_44_btcusdt_binance_btcusdt_binance.csv not exist
# generation 1 with new 30 mutations  15 crossover  0 elite
# [45]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.6843317837192122,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [46]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [47]{
#     "risk_aversion": 0.3632095783410395,
#     "position_multiplier": 100.0,
#     "window_tick": 10.484453489444553,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.8742885004811105,
#     "spread_multiplier": 1.7363635164560982,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [48]{
#     "risk_aversion": 0.3689698155794781,
#     "position_multiplier": 100.0,
#     "window_tick": 16.053585147957833,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [49]{
#     "risk_aversion": 0.5934464097762585,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [50]{
#     "risk_aversion": 0.8656493352185988,
#     "position_multiplier": 100.0,
#     "window_tick": 6.044374199947395,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.406894543407445,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [51]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.1002984054553513,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [52]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [53]{
#     "risk_aversion": 0.8086524817522504,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [54]{
#     "risk_aversion": 0.3626631864307819,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [55]{
#     "risk_aversion": 0.04449903614666011,
#     "position_multiplier": 100.0,
#     "window_tick": 9.476728546258563,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.935314582333979,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [56]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.8169114460447013,
#     "spread_multiplier": 1.1828926208651875,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [57]{
#     "risk_aversion": 0.7578406121836803,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.04370888314806165,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [58]{
#     "risk_aversion": 0.9000000000000001,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 9.999999999999999e-05,
#     "k_default": 1.4354768558466127,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [59]{
#     "risk_aversion": 0.707883431213946,
#     "position_multiplier": 100.0,
#     "window_tick": 7.08410159560265,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.31522238588527,
#     "spread_multiplier": 1.7139677589707487,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [60]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 9.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0174711272231614,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [61]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 16.517613394649743,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [62]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 9.65285252455901,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [63]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 14.570871236637323,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [64]{
#     "risk_aversion": 0.7552273665133513,
#     "position_multiplier": 100.0,
#     "window_tick": 18.317334215339194,
#     "minutes_change_k": 10.0,
#     "quantity": 0.00010000000000000002,
#     "k_default": 1.6545128845237185,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [65]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 6.4636150501732,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.0900461538667277,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [66]{
#     "risk_aversion": 0.6173018955842805,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.7825282318361406,
#     "spread_multiplier": 1.2569512836914465,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [67]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.5359885173499364,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [68]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 16.737245237409134,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [69]{
#     "risk_aversion": 0.3978599847732189,
#     "position_multiplier": 100.0,
#     "window_tick": 5.198056815451914,
#     "minutes_change_k": 10.0,
#     "quantity": 9.999999999999999e-05,
#     "k_default": 1.7827319121945868,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [70]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.1483688892443995,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [71]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.4446041853391125,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [72]{
#     "risk_aversion": 0.5304047619547854,
#     "position_multiplier": 100.0,
#     "window_tick": 16.694489032691806,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.721182035838738,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [73]{
#     "risk_aversion": 0.7528252205066066,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.2676457841788054,
#     "spread_multiplier": 1.2,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [74]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [75]{
#     "risk_aversion": 0.5398780695234149,
#     "position_multiplier": 100.0,
#     "window_tick": 21.175773163072726,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.581923281347199,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [76]{
#     "risk_aversion": 0.8367268370561762,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.925909294635305,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [77]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.8389913584094282,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [78]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.238957736843481,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [79]{
#     "risk_aversion": 0.376197234901759,
#     "position_multiplier": 100.0,
#     "window_tick": 12.045569184298275,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.8320207705670746,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [80]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [81]{
#     "risk_aversion": 0.4054236809542933,
#     "position_multiplier": 100.0,
#     "window_tick": 11.145064741925573,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.9833320140387212,
#     "first_hour": 7.000000000000001,
#     "last_hour": 19.0
# }
# [82]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.21158404924678575,
#     "spread_multiplier": 1.7610421858881387,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [83]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [84]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 21.14770516420878,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0002351682326873,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [85]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.9482960237622806,
#     "spread_multiplier": 1.2203987747952274,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [86]{
#     "risk_aversion": 0.21581643162238115,
#     "position_multiplier": 100.0,
#     "window_tick": 24.55348152411244,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [87]{
#     "risk_aversion": 0.41722193977843286,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [88]{
#     "risk_aversion": 0.05366789247621426,
#     "position_multiplier": 100.0,
#     "window_tick": 22.457249426220812,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.6256058526265553,
#     "spread_multiplier": 1.8,
#     "first_hour": 7.000000000000001,
#     "last_hour": 19.0
# }
# [89]{
#     "risk_aversion": 0.49107766291853533,
#     "position_multiplier": 100.0,
#     "window_tick": 15.810733998169333,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.583038517241632,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# launching AvellanedaStoikov_ga_45
# launching AvellanedaStoikov_ga_46
# launching AvellanedaStoikov_ga_47
# launching AvellanedaStoikov_ga_48
# launching AvellanedaStoikov_ga_49
# launching AvellanedaStoikov_ga_50
# launching AvellanedaStoikov_ga_51
# launching AvellanedaStoikov_ga_52
# launching AvellanedaStoikov_ga_53
# launching AvellanedaStoikov_ga_54
# launching AvellanedaStoikov_ga_55
# launching AvellanedaStoikov_ga_56
# launching AvellanedaStoikov_ga_57
# launching AvellanedaStoikov_ga_58
# launching AvellanedaStoikov_ga_59

#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [95]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [96]{
#     "risk_aversion": 0.8253529243801639,
#     "position_multiplier": 100.0,
#     "window_tick": 7.303522678929949,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.8827584795517036,
#     "first_hour": 7.000000000000001,
#     "last_hour": 19.0
# }
# [97]{
#     "risk_aversion": 0.2705327698593374,
#     "position_multiplier": 100.0,
#     "window_tick": 14.28092775039384,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [98]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.1796044944559818,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [99]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [100]{
#     "risk_aversion": 0.23027796462005273,
#     "position_multiplier": 100.0,
#     "window_tick": 14.406652176377358,
#     "minutes_change_k": 10.0,
#     "quantity": 9.999999999999999e-05,
#     "k_default": 1.2676657100457154,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [101]{
#     "risk_aversion": 0.7862724897469442,
#     "position_multiplier": 100.0,
#     "window_tick": 8.57504782582097,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.4061783881060963,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [102]{
#     "risk_aversion": 0.5523160409323472,
#     "position_multiplier": 100.0,
#     "window_tick": 20.52535136095394,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [103]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.4600806095692636,
#     "spread_multiplier": 2.0,
# ...
#     "window_tick": 23.199569496303514,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [654]{
#     "risk_aversion": 0.16177937822546357,
#     "position_multiplier": 100.0,
#     "window_tick": 10.230787220997783,
#     "minutes_change_k": 10.0,
#     "quantity": 9.999999999999999e-05,
#     "k_default": 1.1601067500286835,
#     "spread_multiplier": 1.2967738002347158,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [655]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [656]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.97254381453313,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [657]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 15.243301418349315,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.0138978695367173,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [658]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.3357570216987285,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [659]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [660]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 9.09150592711816,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [661]{
#     "risk_aversion": 0.8674804555026607,
#     "position_multiplier": 100.0,
#     "window_tick": 21.90036727536502,
#     "minutes_change_k": 10.0,
#     "quantity": 9.999999999999999e-05,
#     "k_default": 0.8302862407394852,
#     "spread_multiplier": 1.66259450933802,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [662]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [663]{
#     "risk_aversion": 0.8251278581500981,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.07329079495735,
#     "spread_multiplier": 2.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [664]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 22.90579289925594,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0972538708870605,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [665]{
#     "risk_aversion": 0.6552587688294109,
#     "position_multiplier": 100.0,
#     "window_tick": 23.149459338300055,
#     "minutes_change_k": 10.0,
#     "quantity": 9.999999999999999e-05,
#     "k_default": 1.1130109262604115,
#     "spread_multiplier": 1.2644370538149636,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [666]{
#     "risk_aversion": 0.8286249959950532,
#     "position_multiplier": 100.0,
#     "window_tick": 19.512423007297713,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.3512048935805239,
#     "spread_multiplier": 1.2504277051699089,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [667]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 16.634751816708675,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.6431080846678214,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [668]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [669]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 7.504404968798902,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.5959812040291939,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [670]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 22.985548268643328,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 1.790959029283507,
#     "spread_multiplier": 1.4434119025159382,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [671]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.5277823311266872,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [672]{
#     "risk_aversion": 0.01,
#     "position_multiplier": 100.0,
#     "window_tick": 21.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.2596235622003766,
#     "first_hour": 7.000000000000001,
#     "last_hour": 19.0
# }
# [673]{
#     "risk_aversion": 0.8620506334602137,
#     "position_multiplier": 100.0,
#     "window_tick": 25.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 0.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# [674]{
#     "risk_aversion": 0.9,
#     "position_multiplier": 100.0,
#     "window_tick": 5.0,
#     "minutes_change_k": 10.0,
#     "quantity": 0.0001,
#     "k_default": 2.0,
#     "spread_multiplier": 1.0,
#     "first_hour": 7.0,
#     "last_hour": 19.0
# }
# launching AvellanedaStoikov_ga_630
# launching AvellanedaStoikov_ga_631
# launching AvellanedaStoikov_ga_632
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# AvellanedaStoikov_ga_674 with 13130 trades
# AvellanedaStoikov best score 0.0073
# best_param_dict {'risk_aversion': 0.01, 'position_multiplier': 100.0, 'window_tick': 20.936773236619324, 'minutes_change_k': 10.0, 'quantity': 0.0001, 'k_default': 1.68688291488258, 'spread_multiplier': 2.0, 'first_hour': 7.0, 'last_hour': 19.0}

# %%
summary_df['best_score_generation']=0
for generation in range(ga_configuration_generations):
    selected=summary_df['generation']<=generation
    selected_single=summary_df['generation']==generation
    best_score_generation=summary_df['score'][selected].max()
    summary_df['best_score_generation'][selected_single]=best_score_generation
summary_df.tail()
# Out:
# E:\Anaconda3\envs\lambda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                             param_dict     score       pnl  \
# 670  {'risk_aversion': 0.9, 'position_multiplier': ...  0.004969  1.210753
# 671  {'risk_aversion': 0.01, 'position_multiplier':...  0.002875  0.569912
# 672  {'risk_aversion': 0.01, 'position_multiplier':...  0.005356  1.125054
# 673  {'risk_aversion': 0.8620506334602137, 'positio...  0.000000  0.000000
# 674  {'risk_aversion': 0.9, 'position_multiplier': ...  0.000962  0.144115
#
#          sharpe trades generation  best_score_generation
# 670    0.004969  13139         14                0.00726
# 671    0.002875  13039         14                0.00726
# 672    0.005356  13181         14                0.00726
# 673 -999.000000      0         14                0.00726
# 674    0.000962  13130         14                0.00726

# %%
summary_df.head(50)
# Out:
#                                            param_dict     score       pnl  \
# 0   {'risk_aversion': 0.16412610253303278, 'positi...  0.005464  1.408309
# 1   {'risk_aversion': 0.9, 'position_multiplier': ...  0.000000  0.000000
# 2   {'risk_aversion': 0.01, 'position_multiplier':...  0.000000  0.000000
# 3   {'risk_aversion': 0.7536606511126509, 'positio...  0.000000  0.000000
# 4   {'risk_aversion': 0.9, 'position_multiplier': ...  0.004135  0.923673
# 5   {'risk_aversion': 0.01, 'position_multiplier':...  0.000934  0.162478
# 6   {'risk_aversion': 0.01, 'position_multiplier':...  0.002337  0.433038
# 7   {'risk_aversion': 0.9, 'position_multiplier': ...  0.002448  0.433366
# 8   {'risk_aversion': 0.8002615850018837, 'positio...  0.000000  0.000000
# 9   {'risk_aversion': 0.9, 'position_multiplier': ...  0.000962  0.144115
# 10  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507708
# 11  {'risk_aversion': 0.01, 'position_multiplier':...  0.003665  0.768924
# 12  {'risk_aversion': 0.01, 'position_multiplier':...  0.004196  0.940373
# 13  {'risk_aversion': 0.1041254222746309, 'positio...  0.004012  0.892586
# 14  {'risk_aversion': 0.3841825009874846, 'positio...  0.000000  0.000000
# 15  {'risk_aversion': 0.9, 'position_multiplier': ...  0.003600  0.669199
# 16  {'risk_aversion': 0.9, 'position_multiplier': ...  0.003457  0.744765
# 17  {'risk_aversion': 0.028035169402415017, 'posit...  0.000000  0.000000
# 18  {'risk_aversion': 0.01, 'position_multiplier':...  0.003915  0.699333
# 19  {'risk_aversion': 0.01, 'position_multiplier':...  0.004264  0.777976
# 20  {'risk_aversion': 0.9, 'position_multiplier': ...  0.003962  0.844370
# 21  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507709
# 22  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507708
# 23  {'risk_aversion': 0.17102523459829272, 'positi...  0.006754  2.054455
# 24  {'risk_aversion': 0.9, 'position_multiplier': ...  0.003495  0.641529
# 25  {'risk_aversion': 0.09131489055720851, 'positi...  0.005511  1.299077
# 26  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507708
# 27  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005550  1.383119
# 28  {'risk_aversion': 0.46672190963386034, 'positi...  0.002026  0.369337
# 29  {'risk_aversion': 0.8066911554752049, 'positio...  0.002450  0.433723
# 30  {'risk_aversion': 0.01, 'position_multiplier':...  0.004854  1.151262
# 31  {'risk_aversion': 0.9, 'position_multiplier': ...  0.000000  0.000000
# 32  {'risk_aversion': 0.30668094406004903, 'positi...  0.000000  0.000000
# 33  {'risk_aversion': 0.06543373489662538, 'positi...  0.004023  0.904516
# 34  {'risk_aversion': 0.838071047202183, 'position...  0.000000  0.000000
# 35  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005437  1.291745
# 36  {'risk_aversion': 0.01, 'position_multiplier':...  0.000000  0.000000
# 37  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507710
# 38  {'risk_aversion': 0.5042796011928666, 'positio...  0.005506  1.464631
# 39  {'risk_aversion': 0.6181028820801832, 'positio...  0.000000  0.000000
# 40  {'risk_aversion': 0.14976010093011222, 'positi...  0.000000  0.000000
# 41  {'risk_aversion': 0.9, 'position_multiplier': ...  0.000000  0.000000
# 42  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507709
# 43  {'risk_aversion': 0.22833946238107128, 'positi...  0.005150  1.367003
# 44  {'risk_aversion': 0.4676889272532547, 'positio...  0.000000  0.000000
# 45  {'risk_aversion': 0.9, 'position_multiplier': ...  0.005811  1.507710
# 46  {'risk_aversion': 0.01, 'position_multiplier':...  0.004196  0.940373
# 47  {'risk_aversion': 0.3632095783410395, 'positio...  0.004134  0.913791
# 48  {'risk_aversion': 0.3689698155794781, 'positio...  0.005326  1.349829
# 49  {'risk_aversion': 0.5934464097762585, 'positio...  0.000000  0.000000
#
#         sharpe trades generation  best_score_generation
# 0     0.005464  13092          0               0.006754
# 1  -999.000000      0          0               0.006754
# 2  -999.000000      0          0               0.006754
# 3  -999.000000      0          0               0.006754
# 4     0.004135  13164          0               0.006754
# 5     0.000934  13141          0               0.006754
# 6     0.002337  13084          0               0.006754
# 7     0.002448  13229          0               0.006754
# 8  -999.000000      0          0               0.006754
# 9     0.000962  13130          0               0.006754
# 10    0.005811  13140          0               0.006754
# 11    0.003665  13113          0               0.006754
# 12    0.004196  13163          0               0.006754
# 13    0.004012  13163          0               0.006754
# 14 -999.000000      0          0               0.006754
# 15    0.003600  13135          0               0.006754
# 16    0.003457  13188          0               0.006754
# 17 -999.000000      0          0               0.006754
# 18    0.003915  13072          0               0.006754
# 19    0.004264  13091          0               0.006754
# 20    0.003962  13140          0               0.006754
# 21    0.005811  13140          0               0.006754
# 22    0.005811  13140          0               0.006754
# 23    0.006754  13162          0               0.006754
# 24    0.003495  13139          0               0.006754
# 25    0.005511  13153          0               0.006754
# 26    0.005811  13140          0               0.006754
# 27    0.005550  13077          0               0.006754
# 28    0.002026  13151          0               0.006754
# 29    0.002450  13229          0               0.006754
# 30    0.004854  13115          0               0.006754
# 31 -999.000000      0          0               0.006754
# 32 -999.000000      0          0               0.006754
# 33    0.004023  13137          0               0.006754
# 34 -999.000000      0          0               0.006754
# 35    0.005437  13086          0               0.006754
# 36 -999.000000      0          0               0.006754
# 37    0.005811  13140          0               0.006754
# 38    0.005506  13147          0               0.006754
# 39 -999.000000      0          0               0.006754
# 40 -999.000000      0          0               0.006754
# 41 -999.000000      0          0               0.006754
# 42    0.005811  13140          0               0.006754
# 43    0.005150  13141          0               0.006754
# 44 -999.000000      0          0               0.006754
# 45    0.005811  13140          1               0.007022
# 46    0.004196  13163          1               0.007022
# 47    0.004134  13212          1               0.007022
# 48    0.005326  13151          1               0.007022
# 49 -999.000000      0          1               0.007022

# %%
summary_df['param_dict'].tail(18)
# Out:
# 657    {'risk_aversion': 0.9, 'position_multiplier': ...
# 658    {'risk_aversion': 0.01, 'position_multiplier':...
# 659    {'risk_aversion': 0.9, 'position_multiplier': ...
# 660    {'risk_aversion': 0.9, 'position_multiplier': ...
# 661    {'risk_aversion': 0.8674804555026607, 'positio...
# 662    {'risk_aversion': 0.01, 'position_multiplier':...
# 663    {'risk_aversion': 0.8251278581500981, 'positio...
# 664    {'risk_aversion': 0.01, 'position_multiplier':...
# 665    {'risk_aversion': 0.6552587688294109, 'positio...
# 666    {'risk_aversion': 0.8286249959950532, 'positio...
# 667    {'risk_aversion': 0.01, 'position_multiplier':...
# 668    {'risk_aversion': 0.01, 'position_multiplier':...
# 669    {'risk_aversion': 0.9, 'position_multiplier': ...
# 670    {'risk_aversion': 0.9, 'position_multiplier': ...
# 671    {'risk_aversion': 0.01, 'position_multiplier':...
# 672    {'risk_aversion': 0.01, 'position_multiplier':...
# 673    {'risk_aversion': 0.8620506334602137, 'positio...
# 674    {'risk_aversion': 0.9, 'position_multiplier': ...
# Name: param_dict, dtype: object

# %%
best_by_generation=summary_df.groupby('generation').max('best_score_generation')
plt.ioff()
best_by_generation['best_score_generation'].plot()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1199.999973990701">

# %%
best_param_dict
# Out:
# {'risk_aversion': 0.01,
#  'position_multiplier': 100.0,
#  'window_tick': 20.936773236619324,
#  'minutes_change_k': 10.0,
#  'quantity': 0.0001,
#  'k_default': 1.68688291488258,
#  'spread_multiplier': 2.0,
#  'first_hour': 7.0,
#  'last_hour': 19.0}

# %%
algorithm.set_parameters(best_param_dict)

# %% [markdown]
# # Train

# %%
# iterations_train=ga_configuration_generations
# algos_per_iteration=ga_configuration.population
# train_simultaneous=ga_configuration_simultaneous

# output_train_list = algorithm.train(
#         instrument_pk=instrument_pk,
#         start_date=start_date_train,
#         end_date=end_date_train,
#         iterations=iterations_train,
#         algos_per_iteration=algos_per_iteration,
#         simultaneous_algos=train_simultaneous,
        
# )

# %%
# name_output=algorithm.algorithm_info
# backtest_result_train=output_train_list[0][name_output]
# backtest_result_train.tail()

# %%
# backtest_result_train['historicalTotalPnl'].plot()
# plt.title('backtest train initial')
# plt.show()

# backtest_result_train['netPosition'].plot()
# plt.title('position train initial')
# plt.show()

# %%
# name_output=algorithm.algorithm_info
# backtest_result_train=output_train_list[-1][name_output]
# backtest_result_train.tail()

# %%
# backtest_result_train['historicalTotalPnl'].plot()
# plt.title('backtest train final')
# plt.show()

# backtest_result_train['netPosition'].plot()
# plt.title('position train final')
# plt.show()

# %% [markdown]
# # Test

# %%
output_test = algorithm.test(
        instrument_pk=instrument_pk,
        start_date=start_date_test,
        end_date=end_date_test,
    )
# Out:
# launching AvellanedaStoikov_AvellanedaStoikov_as_as_notebook_0
# pwd=E:\javif\Coding\Python\market_making_fw\python_lambda\notebooks
# AvellanedaStoikov_AvellanedaStoikov_as_as_notebook_0 finished with code 0
# finished 1 backtests in 0 minutes
# AvellanedaStoikov_AvellanedaStoikov_as_as_notebook_0 with 5167 trades

# %%
name_output=algorithm.algorithm_info
backtest_result_test=output_test[name_output]
backtest_result_test.tail()
# Out:
#           timestamp                     date  verb         price  quantity  \
# 5162  1607450393811  2020-12-08T17:59:53.811  Sell  18927.400645    0.0001
# 5163  1607450394120  2020-12-08T17:59:54.120   Buy  18927.404000    0.0001
# 5164  1607450394385  2020-12-08T17:59:54.385  Sell  18927.402515    0.0001
# 5165  1607450396677  2020-12-08T17:59:56.677   Buy  18927.405885    0.0001
# 5166  1607450399893  2020-12-08T17:59:59.893  Sell  18927.400755    0.0001
#
#       netPosition  avgOpenPrice  netInvestment  historicalRealizedPnl  \
# 5162    -0.005591  18915.996642     126.534901              -0.410063
# 5163    -0.005491  18915.996642     126.534901              -0.411203
# 5164    -0.005591  18916.200646     126.534901              -0.411203
# 5165    -0.005491  18916.200646     126.534901              -0.412324
# 5166    -0.005591  18916.400970     126.534901              -0.412324
#
#       historicalUnrealizedPnl  historicalTotalPnl  numberTrades
# 5162                -0.063784           -0.473847          5170
# 5163                -0.062643           -0.473847          5171
# 5164                -0.062648           -0.473851          5172
# 5165                -0.061515           -0.473839          5173
# 5166                -0.061524           -0.473848          5174

# %%
algorithm.plot_trade_results(raw_trade_pnl_df=backtest_result_test)
plt.show()
# Out:
# plotting trade_results from 2020-12-08 17:00:22.041000 to 2020-12-08 18:59:59.893000
# <img src="data:image/png;base64,..." width="1670">

# %%
if not DEBUG:
    file_output='%s_output.csv'%algorithm.algorithm_info
    backtest_result_test.to_csv(file_output)
    save_notebook_session(session_name)
    send_email(recipient='javifalces@gmail.com',subject='[%s]%s finished'%(datetime.datetime.today(),algorithm.algorithm_info),body='finished %s'%datetime.datetime.today(),file_append=[file_output])
    os.remove(file_output)
# Out:
# notebook session file save as  AvellanedaStoikovNotebook
